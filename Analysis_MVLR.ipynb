# %%
## General imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pingouin as pg
## Latex fonts
from set_tex_fonts import set_latex_font

# %%
# Size of one plot and resolution
pltSizex = 10
pltSizey = 10
dpi = 300
# Fontsize for the different parameters
legFont = 55
xTitleFont = 55
yTitleFont = 55
xLabelFont = 50
yLabelFont = 50
# Set latex font for plots
set_latex_font()

# %%
## Parameters
ablationsList = ['None', 'velocity', 'anthropo', 'forcestorques', 'forces', 'torques', 'Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz']
foldsList     = ['2-fold', '5-fold']
jointsList    = ['shoulder', 'elbow']

# %%
## Import all fitting results
all_JMFittings = pd.read_csv('./all_params/all_eval_metrics_JMLearning.csv', keep_default_na = False, na_values = ['NaN', 'N/A', ''])

## Extract different MVLR results
res_MVLR       = all_JMFittings[all_JMFittings['model'] == 'MVLR']
trainRes_MVLR  = res_MVLR[res_MVLR['type'] == 'train']
evalRes_MVLR   = res_MVLR[res_MVLR['type'] == 'eval']
evalRes_MVLR_s = evalRes_MVLR[evalRes_MVLR['joint'] == 'shoulder']
evalRes_MVLR_e = evalRes_MVLR[evalRes_MVLR['joint'] == 'elbow']

# %%
# fig, axes = plt.subplots(6, 1, figsize = (3*pltSizex, 6*pltSizex), sharex = True)

# sns.boxplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[0])
# sns.stripplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])

# sns.boxplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[1])
# sns.stripplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])

# sns.boxplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[2])
# sns.stripplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[2])

# sns.boxplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[3])
# sns.stripplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[3])

# sns.boxplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[4])
# sns.stripplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[4])

# sns.boxplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[5])
# sns.stripplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_s, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[5])

# %%
# fig, axes = plt.subplots(6, 1, figsize = (3*pltSizex, 6*pltSizex), sharex = True)

# sns.boxplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[0])
# sns.stripplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])

# sns.boxplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[1])
# sns.stripplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])

# sns.boxplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[2])
# sns.stripplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[2])

# sns.boxplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[3])
# sns.stripplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[3])

# sns.boxplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[4])
# sns.stripplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[4])

# sns.boxplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[5])
# sns.stripplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_e, hue = 'fold', hue_order = foldsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[5])

# %%
## Extract different MVLR results
res_MVLR_5f      = all_JMFittings[(all_JMFittings['model'] == 'MVLR') & (all_JMFittings['fold'] == '5-fold')]
trainRes_MVLR_5f = res_MVLR[res_MVLR['type'] == 'train']
evalRes_MVLR_5f  = res_MVLR[res_MVLR['type'] == 'eval']

# %%
fig, axes = plt.subplots(6, 1, figsize = (3*pltSizex, 6*pltSizex), sharex = True)

sns.boxplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[0])
sns.stripplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])

sns.boxplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[1])
sns.stripplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])

sns.boxplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[2])
sns.stripplot(x = 'ablation', y = 'tauAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[2])

sns.boxplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[3])
sns.stripplot(x = 'ablation', y = 'pErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[3])

sns.boxplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[4])
sns.stripplot(x = 'ablation', y = 'vErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[4])

sns.boxplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[5])
sns.stripplot(x = 'ablation', y = 'tauErrStd', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[5])
# Out:
# /tmp/ipykernel_21101/3353740101.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
#   sns.stripplot(x = 'ablation', y = 'posAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])
# /tmp/ipykernel_21101/3353740101.py:7: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
#   sns.stripplot(x = 'ablation', y = 'velAAE', data = evalRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])
# /tmp/ipykernel_21101/3353740101.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
# ...

# %%
fig, axes = plt.subplots(6, 1, figsize = (3*pltSizex, 6*pltSizex), sharex = True)

sns.boxplot(x = 'ablation', y = 'posAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[0])
sns.stripplot(x = 'ablation', y = 'posAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])

sns.boxplot(x = 'ablation', y = 'velAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[1])
sns.stripplot(x = 'ablation', y = 'velAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])

sns.boxplot(x = 'ablation', y = 'tauAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[2])
sns.stripplot(x = 'ablation', y = 'tauAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[2])

sns.boxplot(x = 'ablation', y = 'pErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[3])
sns.stripplot(x = 'ablation', y = 'pErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[3])

sns.boxplot(x = 'ablation', y = 'vErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[4])
sns.stripplot(x = 'ablation', y = 'vErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[4])

sns.boxplot(x = 'ablation', y = 'tauErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, linecolor = 'k', linewidth = 3, showfliers=False, ax = axes[5])
sns.stripplot(x = 'ablation', y = 'tauErrStd', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[5])
# Out:
# /tmp/ipykernel_21101/3094671438.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
#   sns.stripplot(x = 'ablation', y = 'posAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[0])
# /tmp/ipykernel_21101/3094671438.py:7: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
#   sns.stripplot(x = 'ablation', y = 'velAAE', data = trainRes_MVLR_5f, hue = 'joint', hue_order = jointsList, color = 'k', linewidth = 2, dodge = True, edgecolor = 'k', size = 10, ax = axes[1])
# /tmp/ipykernel_21101/3094671438.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
# ...
