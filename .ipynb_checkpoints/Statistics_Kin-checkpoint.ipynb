# %%
## Imports
import os
os.environ["R_HOME"] = r"C:\Program Files\R\R-4.0.3"
os.environ["PATH"]   = r"C:\Program Files\R\R-4.0.3\bin\x64" + ";" + os.environ["PATH"]
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as colmap
import seaborn as sns
from set_tex_fonts import set_latex_font
import pingouin as pg
import motor_control_tools.figures as figures
import motor_control_tools.signal as signal
import manage_expe as me
from motor_control_tools.visual_tools import mean_profiles
import re
import pickle
from scipy.stats import pearsonr
import analyses
# Out:
# ****
# Working on Transp_2DDL data
# ****
# c:\users\nairo\appdata\local\programs\python\python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.12, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# c:\users\nairo\appdata\local\programs\python\python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
## Load population kinematics
all_qtm_data = pd.read_csv("./all_params/Transp_2DDL_index_cut-off-rel-5.csv", encoding = "ISO-8859-1", engine='python')
all_qtm_data = all_qtm_data.groupby(['subject','condition','target','direction']).mean().reset_index()
all_qtm_data = all_qtm_data[all_qtm_data['direction'] == 'forward']

# %% [markdown]
# # Non-parametric Friedman ANOVAS

# %%
# Condition effect MD 
pg.friedman(all_qtm_data, dv = 'MD', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1          Q         p-unc
# Friedman  condition  0.765306      3  32.142857  4.882928e-07

# %%
# Target effect MD 
#pg.friedman(all_qtm_data, dv = 'MD', within = 'target', subject = 'subject')

# %%
# Condition effect curvature
pg.friedman(all_qtm_data, dv = 'curve', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1          Q     p-unc
# Friedman  condition  0.393878      3  16.542857  0.000877

# %%
# Target effect curvature
#pg.friedman(all_qtm_data, dv = 'curve', within = 'target', subject = 'subject')

# %%
# Condition effect mV
#pg.friedman(all_qtm_data, dv = 'mV', within = 'condition', subject = 'subject')

# %%
# Target effect mV
#pg.friedman(all_qtm_data, dv = 'mV', within = 'target', subject = 'subject')

# %%
# Condition effect mA
#pg.friedman(all_qtm_data, dv = 'mA', within = 'condition', subject = 'subject')

# %%
# Target effect mA
#pg.friedman(all_qtm_data, dv = 'mA', within = 'target', subject = 'subject')

# %%
# Condition effect PV
pg.friedman(all_qtm_data, dv = 'PV', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1          Q         p-unc
# Friedman  condition  0.736735      3  30.942857  8.739265e-07

# %%
# Target effect PV
#pg.friedman(all_qtm_data, dv = 'PV', within = 'target', subject = 'subject')

# %%
# Condition effect PA
pg.friedman(all_qtm_data, dv = 'PA', within = 'condition', subject = 'subject')
# Out:
#              Source        W  ddof1          Q     p-unc
# Friedman  condition  0.67551      3  28.371429  0.000003

# %%
# Target effect PA
#pg.friedman(all_qtm_data, dv = 'PA', within = 'target', subject = 'subject')

# %%
# Condition effect rtPV
#pg.friedman(all_qtm_data, dv = 'rtPV', within = 'condition', subject = 'subject')

# %%
# Target effect rtPV
#pg.friedman(all_qtm_data, dv = 'rtPV', within = 'target', subject = 'subject')

# %%
# Condition effect rtPA
#pg.friedman(all_qtm_data, dv = 'rtPA', within = 'condition', subject = 'subject')

# %%
# Target effect rtPA
#pg.friedman(all_qtm_data, dv = 'rtPA', within = 'target', subject = 'subject')

# %% [markdown]
# # Non-parametric Post-hocs

# %%
a = pg.pairwise_ttests(all_qtm_data, dv = 'MD', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
b = pg.pairwise_ttests(all_qtm_data, dv = 'curve', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
c = pg.pairwise_ttests(all_qtm_data, dv = 'mV', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
d = pg.pairwise_ttests(all_qtm_data, dv = 'mA', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
e = pg.pairwise_ttests(all_qtm_data, dv = 'PV', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
f = pg.pairwise_ttests(all_qtm_data, dv = 'PA', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
g = pg.pairwise_ttests(all_qtm_data, dv = 'rtPV', between = ['target','condition'], effsize = 'cohen', parametric = False)

# %%
h = pg.pairwise_ttests(all_qtm_data, dv = 'rtPA', between = ['target','condition'], effsize = 'cohen', parametric = False)
