# %%
## Imports
import os
os.environ["R_HOME"] = r"C:\Program Files\R\R-4.0.3"
os.environ["PATH"]   = r"C:\Program Files\R\R-4.0.3\bin\x64" + ";" + os.environ["PATH"]
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as colmap
import seaborn as sns
from set_tex_fonts import set_latex_font
import pingouin as pg
import motor_control_tools.figures as figures
import motor_control_tools.signal as signal
import manage_expe as me
from motor_control_tools.visual_tools import mean_profiles
import re
import pickle
from scipy.stats import pearsonr
import analyses
# Out:
# ****
# Working on Transp_2DDL data
# ****
# c:\users\nairo\appdata\local\programs\python\python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.12, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# c:\users\nairo\appdata\local\programs\python\python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
## Load population EMG data
# Load shoulder data
df_shoFlex_fw = pd.read_csv("./all_params/sho_flex_fw_Stats.csv", encoding = "ISO-8859-1", engine='python')
df_shoExt_fw = pd.read_csv("./all_params/sho_ext_fw_Stats.csv", encoding = "ISO-8859-1", engine='python')
# Load elbow data
df_elbFlex_fw = pd.read_csv("./all_params/elb_flex_fw_Stats.csv", encoding = "ISO-8859-1", engine='python')
df_elbExt_fw = pd.read_csv("./all_params/elb_ext_fw_Stats.csv", encoding = "ISO-8859-1", engine='python')

# %% [markdown]
# # Non-parametric Friedman ANOVAS

# %% [markdown]
# ## Forward movements

# %%
pg.friedman(df_shoFlex_fw, dv = 'rms fr', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1          Q     p-unc
# Friedman  condition  0.487755      3  20.485714  0.000135

# %%
pg.friedman(df_shoExt_fw, dv = 'rms fr', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1         Q     p-unc
# Friedman  condition  0.079592      3  3.342857  0.341722

# %%
pg.friedman(df_elbFlex_fw, dv = 'rms fr', within = 'condition', subject = 'subject')
# Out:
#              Source        W  ddof1          Q     p-unc
# Friedman  condition  0.67551      3  28.371429  0.000003

# %%
pg.friedman(df_elbExt_fw, dv = 'rms fr', within = 'condition', subject = 'subject')
# Out:
#              Source         W  ddof1          Q     p-unc
# Friedman  condition  0.308163      3  12.942857  0.004762

# %% [markdown]
# # Non-parametric Post-hocs

# %%
a1 = pg.pairwise_ttests(df_shoFlex_fw, dv = 'rms fr', between = ['target','condition'], effsize = 'cohen', parametric = False)
a1
# Out:
#               Contrast target   A     B Paired  Parametric   U-val       Tail  \
# 0               target      -   1     2  False       False  1163.0  two-sided
# 1               target      -   1     3  False       False   844.0  two-sided
# 2               target      -   1     4  False       False   601.0  two-sided
# 3               target      -   1     5  False       False   350.0  two-sided
# 4               target      -   2     3  False       False  1140.0  two-sided
# 5               target      -   2     4  False       False   831.0  two-sided
# 6               target      -   2     5  False       False   533.0  two-sided
# 7               target      -   3     4  False       False  1206.0  two-sided
# 8               target      -   3     5  False       False   833.0  two-sided
# 9               target      -   4     5  False       False  1166.0  two-sided
# 10           condition      -  CL    NE  False       False  3736.0  two-sided
# ...

# %%
a2 = pg.pairwise_ttests(df_elbFlex_fw, dv = 'rms fr', between = ['target','condition'], effsize = 'cohen', parametric = False)
a2
# Out:
#               Contrast target   A     B Paired  Parametric   U-val       Tail  \
# 0               target      -   1     2  False       False  1387.0  two-sided
# 1               target      -   1     3  False       False  1362.0  two-sided
# 2               target      -   1     4  False       False  1281.0  two-sided
# 3               target      -   1     5  False       False  1182.0  two-sided
# 4               target      -   2     3  False       False  1524.0  two-sided
# 5               target      -   2     4  False       False  1439.0  two-sided
# 6               target      -   2     5  False       False  1339.0  two-sided
# 7               target      -   3     4  False       False  1471.0  two-sided
# 8               target      -   3     5  False       False  1382.0  two-sided
# 9               target      -   4     5  False       False  1456.0  two-sided
# 10           condition      -  CL    NE  False       False  4546.0  two-sided
# ...

# %%
a3 = pg.pairwise_ttests(df_elbExt_fw, dv = 'rms fr', between = ['target','condition'], effsize = 'cohen', parametric = False)
